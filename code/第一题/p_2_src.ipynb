# %% [markdown]
# # 图像路径

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
import my_image_processor as mi

#t关于问题一的所有图片路径
    #原图像路径
image_path_1='./Annex 1/Pic1_1.bmp'
image_path_2='./Annex 1/Pic1_2.bmp'
image_path_3='./Annex 1/Pic1_3.bmp'
    #新图像路径
image_new_path_1='./Annex 1/new_image/Pic1_1.png'
image_new_path_2='./Annex 1/new_image/Pic1_2.png'
image_new_path_3='./Annex 1/new_image/Pic1_3.png'
    #边界图像路径
image_bound_path_1='./Annex 1/boundary/pic1_1.png'
image_bound_path_2='./Annex 1/boundary/pic1_2.png'
image_bound_path_3='./Annex 1/boundary/pic1_3.png'

    #热图路径
heat_path_1_X="./Annex 1/图像/Pic_1_1/X-Trans-Image"
heat_path_1_Y="./Annex 1/图像/Pic_1_1/Y-Trans-Image"
heat_path_1=[heat_path_1_X,heat_path_1_Y]
heat_path_2_X="./Annex 1/图像/Pic_1_2/X-Trans-Image"
heat_path_2_Y="./Annex 1/图像/Pic_1_2/Y-Trans-Image"
heat_path_2=[heat_path_2_X,heat_path_2_Y]
heat_path_3_X="./Annex 1/图像/Pic_1_3/X-Trans-Image"
heat_path_3_Y="./Annex 1/图像/Pic_1_3/Y-Trans-Image"
heat_path_3=[heat_path_3_X,heat_path_3_Y]
#图片处理

# %% [markdown]
# # 设置新图片

# %%
p2=mi.image(image_path_2,[])
p2.filtering_bd(image_new_path_2)
# Out:
# count = 208
# True

# %% [markdown]
# # 初始化多边形选择法

# %%
polygon_index=[[-1,False],[-2,False],[-3,True],[-4,True],[-5,True]]

# %% [markdown]
# # 第二个图的多边形拟合并输出像素级别周长

# %%
########################图二#########################
p2=mi.image(image_new_path_2,[],100)


#读取图像轮廓线
#计算sobel算子
p2.set_sobel()
#Devernary_smooth （亚像素级别处理）
p2.Devernary_smooth(heat_path_1)

p2.get_origin_contour_v2(image_bound_path_2,polygon_index)
#p2.get_origin_contour(image_bound_path_2,-3)
# Out:
# 第 1 段轮廓线的周长为：
# 周长为 3924.9823237491814
# 第 2 段轮廓线的周长为：
# 周长为 2267.1145843434724
# 第 3 段轮廓线的周长为：
# 周长为 1497.4231218449877
# 第 4 段轮廓线的周长为：
# 周长为 581.0660424587976
# 第 5 段轮廓线的周长为：
# 周长为 259.73894939300936
# 像素级别轮廓线的总周长为 8530.325021789447
# 周长为 3924.9823237491814
# 亚像素级别的修正周长为 3924.9823237491814
# 总控制点数目为 138
# 周长为 4616.994922828845
# 亚像素级别的修正周长为 4616.994922828845
# 总控制点数目为 197
# 周长为 7399.363363996076
# 亚像素级别的修正周长为 7399.363363996076
# 总控制点数目为 266
# 周长为 8060.979150153835
# 亚像素级别的修正周长为 8060.979150153835
# 总控制点数目为 288
# 周长为 8599.841738853682
# 亚像素级别的修正周长为 8599.841738853682
# 总控制点数目为 302
